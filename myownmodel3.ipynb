# %% [markdown]
# # My Own Fast Frame Prediction Model
#
# A lightweight residual temporal U-Net for Inter4K GOP-8 Y-channel frame prediction. It keeps the same input/output format as `model2.ipynb`: `(B, 7, 1, H, W) -> (B, 1, H, W)`.
#
# Design goal: faster training than the ConvNeXt/Transformer reference while still targeting about 30 dB validation PSNR after training.

# %%
import os, math, random
os.environ.setdefault('KMP_DUPLICATE_LIB_OK', 'TRUE')  # Windows local workaround for duplicate OpenMP runtimes
import shutil
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from pathlib import Path

ON_KAGGLE = os.path.exists('/kaggle/working')

# for item in Path("/kaggle/working").iterdir():
#     if item.is_file():
#         item.unlink()
#     elif item.is_dir():
#         shutil.rmtree(item)

if ON_KAGGLE:
    DATASET_ROOT = '/kaggle/input/datasets/tonmoyk983/sevtone-4-qp-gop8/sevtone_4_QP_GOP8/Inter4K/RAW'
    CKPT_DIR = '/kaggle/working'
else:
    DATASET_ROOT = r'D:\\Dataset\\Inter4K\\60fps\\UHD\\Segments\\sevtone_4_QP_GOP8\\Inter4K\\RAW'
    CKPT_DIR = r'D:\\Dataset\\Inter4K\\60fps\\UHD\\Segments\\sevtone_4_QP_GOP8'

CKPT_DIR = Path(CKPT_DIR)
CKPT_DIR.mkdir(parents=True, exist_ok=True)
BEST_MODEL_PATH = CKPT_DIR / 'myown_fast_best_model.pth'
LAST_CKPT_PATH = CKPT_DIR / 'myown_fast_last_checkpoint.pth'

# Dataset / training config
T = 7
IMG_SIZE = 512
SUBSET_SIZE = 20000
VAL_FRACTION = 0.1
TRAIN_CROP_SIZE = 512   # set to 512 for full-image training; 256 is much faster

# Model / optimizer config
BASE_CHANNELS = 48       # increase to 64 for more PSNR, decrease to 32 for more speed
BATCH_SIZE = 4           # try 12/16 if your GPU has room
EPOCHS = 40
LEARNING_RATE = 2e-4
WEIGHT_DECAY = 1e-4
USE_AMP = True
USE_TQDM = False
BATCH_SUMMARY_EVERY = 100 
NUM_WORKERS = 2
RESUME_CKPT_PATH = "/kaggle/input/models/vaselinek983/check3/pytorch/3/1/myown_fast_last_checkpoint.pth"  # or str(LAST_CKPT_PATH)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.backends.cudnn.benchmark = True

print(f'Running on: {"Kaggle" if ON_KAGGLE else "Local"}')
print(f'DATASET_ROOT : {DATASET_ROOT}')
print(f'Device       : {DEVICE}')
print(f'Best model   : {BEST_MODEL_PATH}')
# Out:
# Running on: Local
# DATASET_ROOT : D:\\Dataset\\Inter4K\\60fps\\UHD\\Segments\\sevtone_4_QP_GOP8\\Inter4K\\RAW
# Device       : cuda
# Best model   : D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\myown_fast_best_model.pth

# %% [markdown]
# ## Dataset
#
# The loader follows `model2.ipynb`: input files are `sample_input_<id>.npy` with shape `(7, 512, 512)`, and target files are `sample_output_<id>.npy` with shape `(1, 512, 512)` or `(512, 512)`.

# %%
class Inter4KDataset(Dataset):
    def __init__(self, root, sample_ids, crop_size=None, random_crop=True):
        self.input_dir = Path(root) / 'Input'
        self.output_dir = Path(root) / 'Output'
        self.ids = list(sample_ids)
        self.crop_size = crop_size
        self.random_crop = random_crop

    def __len__(self):
        return len(self.ids)

    def _crop_pair(self, x, y):
        if self.crop_size is None:
            return x, y
        _, h, w = x.shape
        cs = min(self.crop_size, h, w)
        if self.random_crop:
            top = random.randint(0, h - cs)
            left = random.randint(0, w - cs)
        else:
            top = (h - cs) // 2
            left = (w - cs) // 2
        return x[:, top:top + cs, left:left + cs], y[:, top:top + cs, left:left + cs]

    def __getitem__(self, idx):
        sid = self.ids[idx]
        x = np.load(self.input_dir / f'sample_input_{sid}.npy')
        y = np.load(self.output_dir / f'sample_output_{sid}.npy')
        if y.ndim == 2:
            y = y[np.newaxis]

        x, y = self._crop_pair(x, y)
        x = np.ascontiguousarray(x.astype(np.float32) / 255.0)
        y = np.ascontiguousarray(y.astype(np.float32) / 255.0)

        x = torch.from_numpy(x).unsqueeze(1)  # (7, 1, H, W)
        y = torch.from_numpy(y)               # (1, H, W)
        return x, y


all_ids = list(range(1, SUBSET_SIZE + 1))
split_idx = int(len(all_ids) * (1 - VAL_FRACTION))
train_ids = all_ids[:split_idx]
val_ids = all_ids[split_idx:]

train_ds = Inter4KDataset(DATASET_ROOT, train_ids, crop_size=TRAIN_CROP_SIZE, random_crop=True)
val_ds = Inter4KDataset(DATASET_ROOT, val_ids, crop_size=None, random_crop=False)

loader_kwargs = dict(
    num_workers=NUM_WORKERS,
    pin_memory=(DEVICE.type == 'cuda'),
    persistent_workers=(NUM_WORKERS > 0),
)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, **loader_kwargs)
val_loader = DataLoader(val_ds, batch_size=max(1, BATCH_SIZE // 2), shuffle=False, **loader_kwargs)

print(f'Train: {len(train_ds)} samples | Val: {len(val_ds)} samples')
print(f'Train batches: {len(train_loader)} | Val batches: {len(val_loader)}')
x0, y0 = train_ds[0]
print(f'Sample x shape: {tuple(x0.shape)} | y shape: {tuple(y0.shape)}')
# Out:
# Train: 18000 samples | Val: 2000 samples
# Train batches: 4500 | Val batches: 1000
# Sample x shape: (7, 1, 512, 512) | y shape: (1, 512, 512)

# %% [markdown]
# ## Fast Model
#
# This model uses temporal channel stacking, first-order frame differences, a small two-level U-Net, depthwise-separable residual blocks, and residual prediction from the last input frame.

# %%
class ConvGNAct(nn.Module):
    def __init__(self, in_ch, out_ch, kernel_size=3, stride=1, groups=8):
        super().__init__()
        padding = kernel_size // 2
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size, stride=stride, padding=padding, bias=False),
            nn.GroupNorm(min(groups, out_ch), out_ch),
            nn.SiLU(inplace=True),
        )

    def forward(self, x):
        return self.net(x)


class DSResBlock(nn.Module):
    def __init__(self, channels, expansion=2):
        super().__init__()
        hidden = channels * expansion
        self.net = nn.Sequential(
            nn.Conv2d(channels, channels, 5, padding=2, groups=channels, bias=False),
            nn.GroupNorm(min(8, channels), channels),
            nn.SiLU(inplace=True),
            nn.Conv2d(channels, hidden, 1, bias=False),
            nn.SiLU(inplace=True),
            nn.Conv2d(hidden, channels, 1, bias=False),
            nn.GroupNorm(min(8, channels), channels),
        )

    def forward(self, x):
        return x + self.net(x)


class FastTemporalUNet(nn.Module):
    def __init__(self, T=7, base_ch=48):
        super().__init__()
        self.T = T
        in_ch = T + (T - 1)  # raw frames plus temporal differences

        self.stem = nn.Sequential(
            ConvGNAct(in_ch, base_ch),
            DSResBlock(base_ch),
        )
        self.down1 = nn.Sequential(
            ConvGNAct(base_ch, base_ch * 2, stride=2),
            DSResBlock(base_ch * 2),
            DSResBlock(base_ch * 2),
        )
        self.down2 = nn.Sequential(
            ConvGNAct(base_ch * 2, base_ch * 3, stride=2),
            DSResBlock(base_ch * 3),
            DSResBlock(base_ch * 3),
            DSResBlock(base_ch * 3),
        )
        self.up1 = nn.Sequential(
            ConvGNAct(base_ch * 3 + base_ch * 2, base_ch * 2),
            DSResBlock(base_ch * 2),
        )
        self.up2 = nn.Sequential(
            ConvGNAct(base_ch * 2 + base_ch, base_ch),
            DSResBlock(base_ch),
        )
        self.head = nn.Conv2d(base_ch, 1, 3, padding=1)
        nn.init.zeros_(self.head.weight)
        nn.init.zeros_(self.head.bias)

    def forward(self, x):
        # x: (B, T, 1, H, W)
        B, T_in, C, H, W = x.shape
        assert T_in == self.T and C == 1, f'Expected (B, {self.T}, 1, H, W), got {tuple(x.shape)}'
        frames = x.squeeze(2)                 # (B, T, H, W)
        diffs = frames[:, 1:] - frames[:, :-1] # (B, T-1, H, W)
        z = torch.cat([frames, diffs], dim=1)
        last = x[:, -1]

        s0 = self.stem(z)
        s1 = self.down1(s0)
        s2 = self.down2(s1)

        u1 = F.interpolate(s2, size=s1.shape[-2:], mode='bilinear', align_corners=False)
        u1 = self.up1(torch.cat([u1, s1], dim=1))
        u2 = F.interpolate(u1, size=s0.shape[-2:], mode='bilinear', align_corners=False)
        u2 = self.up2(torch.cat([u2, s0], dim=1))

        delta = self.head(u2)
        return torch.clamp(last + delta, 0.0, 1.0)


model = FastTemporalUNet(T=T, base_ch=BASE_CHANNELS)
model = model.to(DEVICE)

total = sum(p.numel() for p in model.parameters())
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Parameters: {total:,} total | {trainable:,} trainable')
# Out:
# Parameters: 843,889 total | 843,889 trainable

# %%
model.eval()
with torch.no_grad():
    dummy = torch.randn(2, T, 1, TRAIN_CROP_SIZE, TRAIN_CROP_SIZE, device=DEVICE)
    out = model(dummy)
print(f'Input shape : {tuple(dummy.shape)}')
print(f'Output shape: {tuple(out.shape)}')
assert out.shape == (2, 1, TRAIN_CROP_SIZE, TRAIN_CROP_SIZE)
print('Shape verification passed')
# Out:
# Input shape : (2, 7, 1, 512, 512)
# Output shape: (2, 1, 512, 512)
# Shape verification passed

# %% [markdown]
# ## Loss And Metrics
#
# MSE is weighted highest because PSNR is the main target. A small Charbonnier term helps sharper residual learning without making training slow.

# %%
class FastPSNRLoss(nn.Module):
    def __init__(self, w_mse=0.85, w_charb=0.15, eps=1e-3):
        super().__init__()
        self.w_mse = w_mse
        self.w_charb = w_charb
        self.eps = eps

    def forward(self, pred, target):
        mse = F.mse_loss(pred, target)
        charb = torch.sqrt((pred - target) ** 2 + self.eps ** 2).mean()
        return self.w_mse * mse + self.w_charb * charb


def compute_psnr(pred, target, max_val=1.0):
    mse = F.mse_loss(pred, target).item()
    return float('inf') if mse < 1e-12 else 10.0 * math.log10(max_val ** 2 / mse)


def compute_ssim(pred, target, ws=11):
    C1, C2 = 0.01 ** 2, 0.03 ** 2
    coords = torch.arange(ws, dtype=torch.float32, device=pred.device) - ws // 2
    g = torch.exp(-(coords ** 2) / (2 * 1.5 ** 2))
    g /= g.sum()
    k = (g.unsqueeze(0) * g.unsqueeze(1)).unsqueeze(0).unsqueeze(0).to(pred.dtype)
    p = ws // 2
    mu_x = F.conv2d(pred, k, padding=p)
    mu_y = F.conv2d(target, k, padding=p)
    sig_x = F.conv2d(pred * pred, k, padding=p) - mu_x * mu_x
    sig_y = F.conv2d(target * target, k, padding=p) - mu_y * mu_y
    sig_xy = F.conv2d(pred * target, k, padding=p) - mu_x * mu_y
    ssim = ((2 * mu_x * mu_y + C1) * (2 * sig_xy + C2)) / ((mu_x ** 2 + mu_y ** 2 + C1) * (sig_x + sig_y + C2))
    return ssim.mean().item()


criterion = FastPSNRLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=LEARNING_RATE * 0.05)
scaler = torch.amp.GradScaler('cuda', enabled=(USE_AMP and DEVICE.type == 'cuda'))

print('Loss, optimizer, scheduler, PSNR, and SSIM are ready')
# Out:
# Loss, optimizer, scheduler, PSNR, and SSIM are ready

# %% [markdown]
# ## BAR

# %%
@torch.no_grad()
def evaluate_last_frame_baseline(loader, device, max_batches=20):
    run_psnr = 0.0
    n = 0
    for i, (x, y) in enumerate(loader):
        if i >= max_batches:
            break
        x, y = x.to(device), y.to(device)
        pred = x[:, -1]
        run_psnr += compute_psnr(pred, y)
        n += 1
    return run_psnr / max(1, n)


baseline_psnr = evaluate_last_frame_baseline(val_loader, DEVICE)
print(f'Last-input-frame baseline PSNR on first val batches: {baseline_psnr:.2f} dB')
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:1275, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1274 try:
# -> 1275     data = self._data_queue.get(timeout=timeout)
#    1276     return (True, data)
#
# File c:\Users\Tonmoy\miniconda3\Lib\queue.py:209, in Queue.get(self, block, timeout)
#     208 if remaining <= 0.0:
# --> 209     raise Empty
#     210 self.not_empty.wait(remaining)
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 15
#      11         n += 1
#      12     return run_psnr / max(1, n)
# ---> 15 baseline_psnr = evaluate_last_frame_baseline(val_loader, DEVICE)
#      16 print(f'Last-input-frame baseline PSNR on first val batches: {baseline_psnr:.2f} dB')
#
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# Cell In[6], line 5, in evaluate_last_frame_baseline(loader, device, max_batches)
#       3 run_psnr = 0.0
#       4 n = 0
# ----> 5 for i, (x, y) in enumerate(loader):
#       6     if i >= max_batches:
#       7         break
#
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:1482, in _MultiProcessingDataLoaderIter._next_data(self)
#    1479     return self._process_data(data, worker_id)
#    1481 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482 idx, data = self._get_data()
#    1483 self._tasks_outstanding -= 1
#    1484 if self._dataset_kind == _DatasetKind.Iterable:
#    1485     # Check for _IterableDatasetStopIteration
#
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:1434, in _MultiProcessingDataLoaderIter._get_data(self)
#    1432 elif self._pin_memory:
#    1433     while self._pin_memory_thread.is_alive():
# -> 1434         success, data = self._try_get_data()
#    1435         if success:
#    1436             return data
#
# File c:\Users\Tonmoy\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:1288, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1286 if len(failed_workers) > 0:
#    1287     pids_str = ", ".join(str(w.pid) for w in failed_workers)
# -> 1288     raise RuntimeError(
#    1289         f"DataLoader worker (pid(s) {pids_str}) exited unexpectedly"
#    1290     ) from e
#    1291 if isinstance(e, queue.Empty):
#    1292     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 21208, 1880) exited unexpectedly

# %% [markdown]
# ## Training

# %%
def train_one_epoch(model, loader, optimizer, criterion, device, epoch):
    model.train()
    run_loss = 0.0
    run_psnr = 0.0
    run_ssim = 0.0
    window_loss = 0.0
    window_psnr = 0.0
    window_ssim = 0.0
    n = len(loader)
    pbar = tqdm(loader, desc=f'Epoch {epoch} [Train]', leave=False, disable=not USE_TQDM)
    optimizer.zero_grad(set_to_none=True)
    for i, (x, y) in enumerate(pbar):
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        with torch.amp.autocast('cuda', enabled=(USE_AMP and device.type == 'cuda')):
            pred = model(x)
            loss = criterion(pred.float(), y.float())

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)

        pred_f = pred.detach().float()
        y_f = y.float()
        psnr = compute_psnr(pred_f, y_f)
        ssim = compute_ssim(pred_f, y_f)
        run_loss += loss.item()
        run_psnr += psnr
        run_ssim += ssim
        window_loss += loss.item()
        window_psnr += psnr
        window_ssim += ssim
        if USE_TQDM:
            pbar.set_postfix(loss=f'{run_loss / (i + 1):.4f}', psnr=f'{psnr:.2f}dB', ssim=f'{ssim:.4f}')
        should_report = ((i + 1) % BATCH_SUMMARY_EVERY == 0) or ((i + 1) == n)
        if should_report:
            batch_count = BATCH_SUMMARY_EVERY if ((i + 1) % BATCH_SUMMARY_EVERY == 0) else ((i + 1) % BATCH_SUMMARY_EVERY or BATCH_SUMMARY_EVERY)
            start_batch = i + 2 - batch_count
            end_batch = i + 1
            print(
                f'[Train][Epoch {epoch}] Batches {start_batch}-{end_batch}/{n} | '
                f'avg loss={window_loss / batch_count:.4f} | '
                f'avg PSNR={window_psnr / batch_count:.2f}dB | '
                f'avg SSIM={window_ssim / batch_count:.4f}'
            )
            window_loss = 0.0
            window_psnr = 0.0
            window_ssim = 0.0
    return {'loss': run_loss / n, 'psnr': run_psnr / n, 'ssim': run_ssim / n}


@torch.no_grad()
def validate(model, loader, criterion, device):
    model.eval()
    run_loss = 0.0
    run_psnr = 0.0
    run_ssim = 0.0
    window_loss = 0.0
    window_psnr = 0.0
    window_ssim = 0.0
    n = len(loader)
    pbar = tqdm(loader, desc='Validation', leave=False, disable=not USE_TQDM)
    for i, (x, y) in enumerate(pbar):
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        with torch.amp.autocast('cuda', enabled=(USE_AMP and device.type == 'cuda')):
            pred = model(x)
        pred = pred.float()
        y = y.float()
        loss = criterion(pred, y).item()
        psnr = compute_psnr(pred, y)
        ssim = compute_ssim(pred, y)
        run_loss += loss
        run_psnr += psnr
        run_ssim += ssim
        window_loss += loss
        window_psnr += psnr
        window_ssim += ssim
        if USE_TQDM:
            pbar.set_postfix(loss=f'{loss:.4f}', psnr=f'{psnr:.2f}dB', ssim=f'{ssim:.4f}')
        should_report = ((i + 1) % BATCH_SUMMARY_EVERY == 0) or ((i + 1) == n)
        if should_report:
            batch_count = BATCH_SUMMARY_EVERY if ((i + 1) % BATCH_SUMMARY_EVERY == 0) else ((i + 1) % BATCH_SUMMARY_EVERY or BATCH_SUMMARY_EVERY)
            start_batch = i + 2 - batch_count
            end_batch = i + 1
            print(
                f'[Val] Batches {start_batch}-{end_batch}/{n} | '
                f'avg loss={window_loss / batch_count:.4f} | '
                f'avg PSNR={window_psnr / batch_count:.2f}dB | '
                f'avg SSIM={window_ssim / batch_count:.4f}'
            )
            window_loss = 0.0
            window_psnr = 0.0
            window_ssim = 0.0
    return {'loss': run_loss / n, 'psnr': run_psnr / n, 'ssim': run_ssim / n}


print('train_one_epoch and validate defined')

# %%
start_epoch = 1
best_psnr = 0.0
history = {'train_loss': [], 'train_psnr': [], 'val_loss': [], 'val_psnr': [], 'val_ssim': []}

if RESUME_CKPT_PATH and os.path.exists(RESUME_CKPT_PATH):
    print(f'Loading checkpoint: {RESUME_CKPT_PATH}')
    ckpt = torch.load(RESUME_CKPT_PATH, map_location=DEVICE)
    if isinstance(ckpt, dict) and 'model' in ckpt:
        model.load_state_dict(ckpt['model'])
        optimizer.load_state_dict(ckpt['optimizer'])
        if 'scheduler' in ckpt:
            scheduler.load_state_dict(ckpt['scheduler'])
        start_epoch = ckpt.get('epoch', 0) + 1
        best_psnr = ckpt.get('best_psnr', 0.0)
        history = ckpt.get('history', history)
    else:
        model.load_state_dict(ckpt)
    print(f'Resumed from epoch {start_epoch} | best PSNR: {best_psnr:.2f} dB')
else:
    print('No checkpoint loaded - training from scratch')

# %%
for epoch in range(start_epoch, start_epoch + EPOCHS):
    print(f'\n{"=" * 55}')
    print(f'Epoch {epoch}  (run epochs {start_epoch} - {start_epoch + EPOCHS - 1})')
    print(f'{"=" * 55}')

    tr = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE, epoch)
    va = validate(model, val_loader, criterion, DEVICE)
    scheduler.step()

    history['train_loss'].append(tr['loss'])
    history['train_psnr'].append(tr['psnr'])
    history['val_loss'].append(va['loss'])
    history['val_psnr'].append(va['psnr'])
    history['val_ssim'].append(va['ssim'])

    print(f"Train loss={tr['loss']:.4f}  PSNR={tr['psnr']:.2f}dB")
    print(f"Val   loss={va['loss']:.4f}  PSNR={va['psnr']:.2f}dB  SSIM={va['ssim']:.4f}")

    if va['psnr'] > best_psnr:
        best_psnr = va['psnr']
        torch.save(model.state_dict(), BEST_MODEL_PATH)
        print(f'[BEST] PSNR={best_psnr:.2f}dB -> {BEST_MODEL_PATH}')

    torch.save({
        'epoch': epoch,
        'best_psnr': best_psnr,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'scheduler': scheduler.state_dict(),
        'history': history,
        'config': {
            'T': T,
            'base_channels': BASE_CHANNELS,
            'train_crop_size': TRAIN_CROP_SIZE,
            'batch_size': BATCH_SIZE,
            'learning_rate': LEARNING_RATE,
        },
    }, LAST_CKPT_PATH)

print(f'\nRun complete. Best Val PSNR: {best_psnr:.2f} dB')
print(f'Inference weights: {BEST_MODEL_PATH}')
print(f'Resume checkpoint : {LAST_CKPT_PATH}')

# %% [markdown]
# ## Curves And Demo

# %%
epochs_seen = range(1, len(history['val_psnr']) + 1)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(epochs_seen, history['train_loss'], label='Train', marker='o')
axes[0].plot(epochs_seen, history['val_loss'], label='Val', marker='s')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(epochs_seen, history['train_psnr'], label='Train', marker='o')
axes[1].plot(epochs_seen, history['val_psnr'], label='Val', marker='s')
axes[1].set_title('PSNR (dB)')
axes[1].set_xlabel('Epoch')
axes[1].legend()
axes[1].grid(True)

axes[2].plot(epochs_seen, history['val_ssim'], color='purple', marker='o')
axes[2].set_title('Val SSIM')
axes[2].set_xlabel('Epoch')
axes[2].grid(True)

plt.suptitle('FastTemporalUNet Training Curves')
plt.tight_layout()
curves_path = CKPT_DIR / 'myown_fast_training_curves.png'
plt.savefig(curves_path, dpi=150, bbox_inches='tight')
print(f'Curves saved -> {curves_path}')
plt.show()

# %%
def load_single_sample(sid):
    ds = Inter4KDataset(DATASET_ROOT, [sid], crop_size=None, random_crop=False)
    x, y = ds[0]
    return x.unsqueeze(0), y.unsqueeze(0)


if BEST_MODEL_PATH.exists():
    model.load_state_dict(torch.load(BEST_MODEL_PATH, map_location=DEVICE))
model.eval()

DEMO_ID = 1
x_d, y_d = load_single_sample(DEMO_ID)
with torch.no_grad():
    y_p = model(x_d.to(DEVICE)).cpu()

psnr_v = compute_psnr(y_p, y_d)
ssim_v = compute_ssim(y_p.to(DEVICE), y_d.to(DEVICE))

fig, axes = plt.subplots(1, T + 2, figsize=(3 * (T + 2), 3.5))
for t in range(T):
    axes[t].imshow(x_d[0, t, 0].numpy(), cmap='gray', vmin=0, vmax=1)
    axes[t].set_title(f'Input t={t}', fontsize=8)
    axes[t].axis('off')

axes[T].imshow(y_d[0, 0].numpy(), cmap='gray', vmin=0, vmax=1)
axes[T].set_title('Target', fontsize=8)
axes[T].axis('off')

axes[T + 1].imshow(y_p[0, 0].numpy(), cmap='gray', vmin=0, vmax=1)
axes[T + 1].set_title(f'Predicted\nPSNR={psnr_v:.2f}dB\nSSIM={ssim_v:.4f}', fontsize=8)
axes[T + 1].axis('off')

plt.suptitle(f'Sample {DEMO_ID} - FastTemporalUNet Output')
plt.tight_layout()
plt.show()

# %%
import csv
import re

TESTING_CLASSD2_ROOT = Path(DATASET_ROOT).parent.parent / 'Original/WQVGA/ClassC/encoded_C'
ORIGINAL_CLASSD_ROOT = Path(DATASET_ROOT).parent.parent / 'Original/WQVGA/ClassC'
EVAL_MODEL_PATH = CKPT_DIR / 'myown_fast_best_model_final.pth'
if not EVAL_MODEL_PATH.exists():
    EVAL_MODEL_PATH = BEST_MODEL_PATH

RESIZE_INFERENCE_TO_512 = True
INFERENCE_SIZE = 512
GOP_SIZE = 8
OUTPUT_ROOT = CKPT_DIR / 'frame_prediction_csvs2/ClassC'
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

# ── Resolution mode ────────────────────────────────────────────────────────────
# Set True  → all YUVs are assumed to be 416x240 (no path-parsing needed).
# Set False → resolution is detected dynamically from the folder / file name.
USE_FIXED_RESOLUTION = True
FIXED_YUV_WIDTH  = 416
FIXED_YUV_HEIGHT = 240
# ─────────────────────────────────────────────────────────────────────────────

base_model = model.module if isinstance(model, nn.DataParallel) else model
base_model.load_state_dict(torch.load(EVAL_MODEL_PATH, map_location=DEVICE))
base_model.eval()
print(f'Loaded checkpoint: {EVAL_MODEL_PATH}')
print(f'Testing root      : {TESTING_CLASSD2_ROOT}')
print(f'Original root     : {ORIGINAL_CLASSD_ROOT}')
print(f'CSV output root   : {OUTPUT_ROOT}')
res_label = f'fixed {FIXED_YUV_WIDTH}x{FIXED_YUV_HEIGHT}' if USE_FIXED_RESOLUTION else 'dynamic (parsed from path)'
print(f'Resolution mode   : {res_label}')


def read_yuv420_y_frames(yuv_path, width, height):
    frame_size = width * height * 3 // 2
    raw = np.fromfile(yuv_path, dtype=np.uint8)
    if raw.size % frame_size != 0:
        raise ValueError(f'File size mismatch for {yuv_path} (expected multiples of {frame_size} bytes per frame)')
    num_frames = raw.size // frame_size
    y_size = width * height
    frames = raw.reshape(num_frames, frame_size)
    y_frames = frames[:, :y_size].reshape(num_frames, height, width)
    return y_frames


def parse_resolution(folder_name):
    match = re.search(r'(\d+)x(\d+)', folder_name)
    if not match:
        raise ValueError(f'Could not parse resolution from {folder_name}')
    return int(match.group(1)), int(match.group(2))


def find_resolution_from_path(path):
    """Return (width, height) for *path*.

    If USE_FIXED_RESOLUTION is True the global FIXED_YUV_WIDTH / FIXED_YUV_HEIGHT
    constants are returned immediately without any path inspection.
    Otherwise the resolution is parsed dynamically from the path components.
    """
    if USE_FIXED_RESOLUTION:
        return FIXED_YUV_WIDTH, FIXED_YUV_HEIGHT
    for part in [path.name, *path.parts]:
        match = re.search(r'(\d+)x(\d+)', part)
        if match:
            return int(match.group(1)), int(match.group(2))
    raise ValueError(f'Could not parse resolution from path {path}')


def resolve_original_yuv_path(recon_yuv_path):
    video_folder = recon_yuv_path.parent.parent.name
    if not ORIGINAL_CLASSD_ROOT.exists():
        raise FileNotFoundError(f'Original Class D root not found: {ORIGINAL_CLASSD_ROOT}')

    candidates = [p for p in ORIGINAL_CLASSD_ROOT.rglob('*.yuv') if p != recon_yuv_path]
    if not candidates:
        raise FileNotFoundError(f'No original YUV files found under {ORIGINAL_CLASSD_ROOT}')

    def score(path):
        path_text = str(path).lower()
        score_value = 0
        if path.parent.name == video_folder:
            score_value += 10
        if path.stem == video_folder:
            score_value += 8
        if video_folder.lower() in path.stem.lower():
            score_value += 6
        if 'qp_' not in path.name.lower():
            score_value += 2
        if 'testing_classd2' not in path_text:
            score_value += 1
        return score_value

    ranked = sorted(((score(p), p) for p in candidates), key=lambda item: (item[0], len(item[1].parts)), reverse=True)
    best_score, best_path = ranked[0]
    if best_score <= 0:
        raise FileNotFoundError(f'Could not match an original YUV for {recon_yuv_path}')
    return best_path


def resize_frame_stack(frames, size=INFERENCE_SIZE):
    if not RESIZE_INFERENCE_TO_512:
        return frames
    tensor = torch.from_numpy(frames).unsqueeze(1).float()
    tensor = F.interpolate(tensor, size=(size, size), mode='bilinear', align_corners=False)
    return tensor.squeeze(1).cpu().numpy()


def load_frame_stack(yuv_path):
    width, height = find_resolution_from_path(yuv_path)
    frames = read_yuv420_y_frames(yuv_path, width, height).astype(np.float32) / 255.0
    return resize_frame_stack(frames)


def frame_tensor(frames, frame_index):
    return torch.from_numpy(frames[frame_index - 1:frame_index]).unsqueeze(1).to(DEVICE)


def parse_encode_log(log_path):
    frame_pattern = re.compile(r'POC\s+(\d+).*?\[Y\s+([0-9.]+)\s+dB', re.IGNORECASE)
    summary_pattern = re.compile(r'^\s*(\d+)\s+a\s+([0-9.]+)\s+([0-9.]+)\s+([0-9.]+)\s+([0-9.]+)\s+([0-9.]+)\s*$', re.IGNORECASE)
    frame_rows = []
    summary = {}
    with open(log_path, 'r', encoding='utf-8', errors='ignore') as handle:
        for line in handle:
            frame_match = frame_pattern.search(line)
            if frame_match:
                poc = int(frame_match.group(1))
                frame_rows.append({
                    'frame_index': poc + 1,
                    'source': 'vvc',
                    'y_psnr': float(frame_match.group(2)),
                    'ssim': '',
                    'note': 'encode_log',
                })
                continue
            summary_match = summary_pattern.match(line)
            if summary_match:
                summary = {
                    'frame_count': int(summary_match.group(1)),
                    'bitrate': float(summary_match.group(2)),
                    'avg_y_psnr': float(summary_match.group(3)),
                    'avg_u_psnr': float(summary_match.group(4)),
                    'avg_v_psnr': float(summary_match.group(5)),
                    'avg_yuv_psnr': float(summary_match.group(6)),
                }
    if not frame_rows:
        raise ValueError(f'No frame PSNR entries found in {log_path}')
    return frame_rows, summary


def model_target_frames(max_frame_index):
    return list(range(GOP_SIZE, max_frame_index + 1, GOP_SIZE))


@torch.no_grad()
def build_vvc_rows(frame_rows, recon_frames, orig_frames):
    max_frame_index = max(row['frame_index'] for row in frame_rows)
    if recon_frames.shape[0] < max_frame_index:
        raise ValueError(f'Need at least {max_frame_index} reconstructed frames, found {recon_frames.shape[0]}')
    if orig_frames.shape[0] < max_frame_index:
        raise ValueError(f'Need at least {max_frame_index} original frames, found {orig_frames.shape[0]}')

    vvc_rows = []
    for row in frame_rows:
        frame_index = row['frame_index']
        recon = frame_tensor(recon_frames, frame_index)
        orig = frame_tensor(orig_frames, frame_index)
        vvc_rows.append({
            'row_type': 'frame',
            'frame_index': frame_index,
            'source': 'vvc',
            'y_psnr': row['y_psnr'],
            'ssim': compute_ssim(recon, orig),
            'note': 'encode_log_psnr_computed_ssim',
        })
    return vvc_rows


@torch.no_grad()
def predict_model_rows(recon_frames, orig_frames, target_frames):
    if not target_frames:
        raise ValueError('No GOP target frames were found for model prediction')
    if recon_frames.shape[0] < max(target_frames):
        raise ValueError(f'Need at least {max(target_frames)} reconstructed frames, found {recon_frames.shape[0]}')
    if orig_frames.shape[0] < max(target_frames):
        raise ValueError(f'Need at least {max(target_frames)} original frames, found {orig_frames.shape[0]}')

    rows = {}
    for frame_index in target_frames:
        start = frame_index - GOP_SIZE
        end = frame_index - 1
        if start < 0:
            raise ValueError(f'Frame {frame_index} does not have {GOP_SIZE - 1} previous input frames')
        x_np = recon_frames[start:end]
        y_np = orig_frames[frame_index - 1:frame_index]
        x = torch.from_numpy(x_np).unsqueeze(0).unsqueeze(2).to(DEVICE)
        y = torch.from_numpy(y_np).unsqueeze(0).to(DEVICE)
        pred = base_model(x).float()
        rows[frame_index] = {
            'row_type': 'frame',
            'frame_index': frame_index,
            'source': 'model',
            'y_psnr': compute_psnr(pred.cpu(), y.cpu()),
            'ssim': compute_ssim(pred.cpu(), y.cpu()),
            'note': f'predicted from frames {frame_index - (GOP_SIZE - 1)}-{frame_index - 1}',
        }
    return rows


def build_mixed_rows(vvc_rows, model_rows):
    mixed_rows = []
    for vvc_row in sorted(vvc_rows, key=lambda row: row['frame_index']):
        frame_index = vvc_row['frame_index']
        if frame_index in model_rows:
            mixed_rows.append(model_rows[frame_index])
        else:
            mixed_rows.append(vvc_row)
    return mixed_rows


def mean_metric(rows, metric):
    values = [row[metric] for row in rows if row.get(metric) != '']
    return float(np.mean(values)) if values else ''


def summarize_report_rows(rows, report_name, log_summary, target_frames):
    vvc_rows = [row for row in rows if row['source'] == 'vvc']
    model_rows = [row for row in rows if row['source'] == 'model']
    summary_rows = [
        {
            'row_type': 'summary',
            'video_id': '',
            'qp': '',
            'frame_index': 'all',
            'source': f'{report_name}_mean',
            'y_psnr': mean_metric(rows, 'y_psnr'),
            'ssim': mean_metric(rows, 'ssim'),
            'note': f"encode_log_reported_yuv_psnr={log_summary.get('avg_yuv_psnr', '')}",
        },
    ]
    if vvc_rows:
        summary_rows.append({
            'row_type': 'summary',
            'video_id': '',
            'qp': '',
            'frame_index': 'vvc',
            'source': 'vvc_mean_in_report',
            'y_psnr': mean_metric(vvc_rows, 'y_psnr'),
            'ssim': mean_metric(vvc_rows, 'ssim'),
            'note': 'vvc rows included in this CSV',
        })
    if model_rows:
        summary_rows.append({
            'row_type': 'summary',
            'video_id': '',
            'qp': '',
            'frame_index': 'model',
            'source': 'model_mean_in_report',
            'y_psnr': mean_metric(model_rows, 'y_psnr'),
            'ssim': mean_metric(model_rows, 'ssim'),
            'note': f'model frames {target_frames}',
        })
    return summary_rows


def write_report_csv(csv_path, rows, summary_rows, video_id, qp):
    fieldnames = [
        'row_type',
        'video_id',
        'qp',
        'frame_index',
        'source',
        'y_psnr',
        'ssim',
        'note',
    ]
    with open(csv_path, 'w', newline='', encoding='utf-8') as handle:
        writer = csv.DictWriter(handle, fieldnames=fieldnames)
        writer.writeheader()
        for row in rows + summary_rows:
            output_row = {
                'row_type': row.get('row_type', 'frame'),
                'video_id': video_id,
                'qp': qp,
                'frame_index': row.get('frame_index', ''),
                'source': row.get('source', ''),
                'y_psnr': row.get('y_psnr', ''),
                'ssim': row.get('ssim', ''),
                'note': row.get('note', ''),
            }
            writer.writerow(output_row)


def process_qp_folder(qp_dir):
    log_path = qp_dir / 'encode.log'
    if not log_path.exists():
        raise FileNotFoundError(f'Missing encode.log in {qp_dir}')

    frame_rows, log_summary = parse_encode_log(log_path)
    recon_yuv_paths = sorted(qp_dir.glob('*.yuv'))
    if not recon_yuv_paths:
        raise FileNotFoundError(f'No reconstructed YUV files found in {qp_dir}')

    video_id = qp_dir.parent.name
    qp = qp_dir.name
    written_csvs = []

    for recon_yuv_path in recon_yuv_paths:
        orig_yuv_path = resolve_original_yuv_path(recon_yuv_path)
        recon_frames = load_frame_stack(recon_yuv_path)
        orig_frames = load_frame_stack(orig_yuv_path)
        max_frame_index = max(row['frame_index'] for row in frame_rows)
        target_frames = model_target_frames(max_frame_index)

        vvc_rows = build_vvc_rows(frame_rows, recon_frames, orig_frames)
        model_rows = predict_model_rows(recon_frames, orig_frames, target_frames)
        mixed_rows = build_mixed_rows(vvc_rows, model_rows)

        vvc_summary_rows = summarize_report_rows(vvc_rows, 'vvc_all', log_summary, target_frames)
        mixed_summary_rows = summarize_report_rows(mixed_rows, 'vvc_1_7_model_8', log_summary, target_frames)

        out_dir = OUTPUT_ROOT / video_id / qp
        out_dir.mkdir(parents=True, exist_ok=True)
        vvc_csv_path = out_dir / f'{recon_yuv_path.stem}_vvc_all.csv'
        mixed_csv_path = out_dir / f'{recon_yuv_path.stem}_vvc_1_7_model_8.csv'

        write_report_csv(vvc_csv_path, vvc_rows, vvc_summary_rows, video_id, qp)
        write_report_csv(mixed_csv_path, mixed_rows, mixed_summary_rows, video_id, qp)
        written_csvs.extend([vvc_csv_path, mixed_csv_path])

        print(f'Wrote {vvc_csv_path}')
        print(f'Wrote {mixed_csv_path}')
        print(f"  VVC all Y-PSNR mean       : {mean_metric(vvc_rows, 'y_psnr'):.4f}")
        print(f"  VVC all SSIM mean         : {mean_metric(vvc_rows, 'ssim'):.4f}")
        print(f"  VVC reported YUV-PSNR     : {log_summary.get('avg_yuv_psnr', float('nan')):.4f}")
        print(f"  Mixed Y-PSNR mean         : {mean_metric(mixed_rows, 'y_psnr'):.4f}")
        print(f"  Mixed SSIM mean           : {mean_metric(mixed_rows, 'ssim'):.4f}")
        print(f"  Model target mean Y-PSNR  : {mean_metric(list(model_rows.values()), 'y_psnr'):.4f}")
        print(f"  Model target mean SSIM    : {mean_metric(list(model_rows.values()), 'ssim'):.4f}")

    return written_csvs


results = []
for qp_dir in sorted(TESTING_CLASSD2_ROOT.glob('*/*')):
    if qp_dir.is_dir() and qp_dir.name.startswith('QP_'):
        results.extend(process_qp_folder(qp_dir))

if not results:
    raise RuntimeError(f'No QP folders found under {TESTING_CLASSD2_ROOT}')

print(f'\nFinished CSV export. Wrote {len(results)} CSV files.')
# Out:
# Loaded checkpoint: D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\myown_fast_best_model_final.pth
# Testing root      : D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\WQVGA\ClassC\encoded_C
# Original root     : D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\WQVGA\ClassC
# CSV output root   : D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC
# Resolution mode   : fixed 416x240
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_37\C_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_37\C_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 32.4440
#   VVC all SSIM mean         : 0.9082
#   VVC reported YUV-PSNR     : 33.3345
#   Mixed Y-PSNR mean         : 32.0919
#   Mixed SSIM mean           : 0.9038
#   Model target mean Y-PSNR  : 29.5989
#   Model target mean SSIM    : 0.8731
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_42\C_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_42\C_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 29.3408
#   VVC all SSIM mean         : 0.8570
#   VVC reported YUV-PSNR     : 30.4995
#   Mixed Y-PSNR mean         : 29.2015
#   Mixed SSIM mean           : 0.8537
#   Model target mean Y-PSNR  : 28.2145
#   Model target mean SSIM    : 0.8313
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_47\C_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_47\C_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 26.2751
#   VVC all SSIM mean         : 0.7797
#   VVC reported YUV-PSNR     : 27.4334
#   Mixed Y-PSNR mean         : 26.2648
#   Mixed SSIM mean           : 0.7777
#   Model target mean Y-PSNR  : 26.1711
#   Model target mean SSIM    : 0.7646
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_51\C_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BasketballDrill_832x480_50_C_416x240\QP_51\C_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 24.2385
#   VVC all SSIM mean         : 0.7131
#   VVC reported YUV-PSNR     : 25.4481
#   Mixed Y-PSNR mean         : 24.2577
#   Mixed SSIM mean           : 0.7121
#   Model target mean Y-PSNR  : 24.3250
#   Model target mean SSIM    : 0.7039
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_37\C_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_37\C_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 31.1706
#   VVC all SSIM mean         : 0.9175
#   VVC reported YUV-PSNR     : 32.3096
#   Mixed Y-PSNR mean         : 31.1664
#   Mixed SSIM mean           : 0.9152
#   Model target mean Y-PSNR  : 31.0958
#   Model target mean SSIM    : 0.8984
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_42\C_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_42\C_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 27.9635
#   VVC all SSIM mean         : 0.8495
#   VVC reported YUV-PSNR     : 29.3366
#   Mixed Y-PSNR mean         : 28.0473
#   Mixed SSIM mean           : 0.8477
#   Model target mean Y-PSNR  : 28.6195
#   Model target mean SSIM    : 0.8356
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_47\C_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_47\C_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 25.1228
#   VVC all SSIM mean         : 0.7594
#   VVC reported YUV-PSNR     : 26.5228
#   Mixed Y-PSNR mean         : 25.2346
#   Mixed SSIM mean           : 0.7591
#   Model target mean Y-PSNR  : 25.9901
#   Model target mean SSIM    : 0.7546
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_51\C_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\BQMall_832x480_60_C_416x240\QP_51\C_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 22.9366
#   VVC all SSIM mean         : 0.6688
#   VVC reported YUV-PSNR     : 24.3752
#   Mixed Y-PSNR mean         : 23.0263
#   Mixed SSIM mean           : 0.6688
#   Model target mean Y-PSNR  : 23.6701
#   Model target mean SSIM    : 0.6698
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_37\C_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_37\C_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 28.6306
#   VVC all SSIM mean         : 0.8674
#   VVC reported YUV-PSNR     : 29.8119
#   Mixed Y-PSNR mean         : 28.6986
#   Mixed SSIM mean           : 0.8625
#   Model target mean Y-PSNR  : 29.0848
#   Model target mean SSIM    : 0.8272
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_42\C_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_42\C_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 25.3205
#   VVC all SSIM mean         : 0.7355
#   VVC reported YUV-PSNR     : 26.7294
#   Mixed Y-PSNR mean         : 25.4911
#   Mixed SSIM mean           : 0.7326
#   Model target mean Y-PSNR  : 26.6776
#   Model target mean SSIM    : 0.7135
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_47\C_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_47\C_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 22.8077
#   VVC all SSIM mean         : 0.5870
#   VVC reported YUV-PSNR     : 24.2346
#   Mixed Y-PSNR mean         : 22.9859
#   Mixed SSIM mean           : 0.5863
#   Model target mean Y-PSNR  : 24.2295
#   Model target mean SSIM    : 0.5831
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_51\C_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\PartyScene_832x480_50_C_416x240\QP_51\C_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 21.4400
#   VVC all SSIM mean         : 0.5073
#   VVC reported YUV-PSNR     : 22.8543
#   Mixed Y-PSNR mean         : 21.5981
#   Mixed SSIM mean           : 0.5077
#   Model target mean Y-PSNR  : 22.6722
#   Model target mean SSIM    : 0.5122
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_37\C_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_37\C_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 30.3815
#   VVC all SSIM mean         : 0.8748
#   VVC reported YUV-PSNR     : 31.3690
#   Mixed Y-PSNR mean         : 29.7103
#   Mixed SSIM mean           : 0.8606
#   Model target mean Y-PSNR  : 24.9642
#   Model target mean SSIM    : 0.7588
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_42\C_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_42\C_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 27.9349
#   VVC all SSIM mean         : 0.8179
#   VVC reported YUV-PSNR     : 29.1165
#   Mixed Y-PSNR mean         : 27.5084
#   Mixed SSIM mean           : 0.8074
#   Model target mean Y-PSNR  : 24.5171
#   Model target mean SSIM    : 0.7308
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_47\C_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_47\C_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 25.4835
#   VVC all SSIM mean         : 0.7565
#   VVC reported YUV-PSNR     : 26.6343
#   Mixed Y-PSNR mean         : 25.2036
#   Mixed SSIM mean           : 0.7488
#   Model target mean Y-PSNR  : 23.3236
#   Model target mean SSIM    : 0.6948
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_51\C_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32_vvc_all.csv
# Wrote D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\ClassC\RaceHorses_832x480_30_C_416x240\QP_51\C_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32_vvc_1_7_model_8.csv
#   VVC all Y-PSNR mean       : 23.5236
#   VVC all SSIM mean         : 0.7014
#   VVC reported YUV-PSNR     : 24.6589
#   Mixed Y-PSNR mean         : 23.4077
#   Mixed SSIM mean           : 0.6976
#   Model target mean Y-PSNR  : 22.6837
#   Model target mean SSIM    : 0.6698
#
# Finished CSV export. Wrote 32 CSV files.

# %%
import csv
import re
from pathlib import Path

# Bitrate formulas copied from Archive/compute_bitrate.py:
#   reported_bitrate = (total_bits / total_frames) * frame_rate / 1000
#   new_bitrate      = (new_total_bits / total_frames) * frame_rate / 1000

BITRATE_TESTING_ROOT = Path(DATASET_ROOT).parent.parent / 'Original/WQVGA/ClassC/encoded_C'
BITRATE_OUTPUT_ROOT = CKPT_DIR / 'frame_prediction_csvs2'
BITRATE_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
BITRATE_SUMMARY_CSV = BITRATE_OUTPUT_ROOT / 'bitrate_summary_C.csv'

EXCLUDED_FRAME_INDICES = [8, 16, 24, 32]
FORCED_FRAME_RATE = None  # set to 50 or 60 to force fps; None derives it from the VTM summary

BITRATE_FRAME_RE = re.compile(r'POC\s+(\d+)\s+.*?\)\s+(\d+)\s+bits')
BITRATE_SUMMARY_RE = re.compile(
    r'^\s*(\d+)\s+a\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s*$',
    re.MULTILINE,
)


def parse_bitrate_log(log_path):
    text = Path(log_path).read_text(encoding='utf-8', errors='ignore')
    frames = {int(poc): int(bits) for poc, bits in BITRATE_FRAME_RE.findall(text)}
    if not frames:
        raise ValueError(f"No per-frame 'POC ... bits' lines found in {log_path}")

    summary_match = BITRATE_SUMMARY_RE.search(text)
    if not summary_match:
        raise ValueError(f'Could not find VTM summary line in {log_path}')

    return {
        'frames': frames,
        'total_frames': int(summary_match.group(1)),
        'reported_bitrate_kbps': float(summary_match.group(2)),
    }


def derive_frame_rate(total_bits, total_frames, reported_bitrate_kbps):
    return reported_bitrate_kbps * 1000.0 * total_frames / total_bits


def calculate_bitrate_rows(log_path, excluded_frame_indices=EXCLUDED_FRAME_INDICES):
    parsed = parse_bitrate_log(log_path)
    frames = parsed['frames']
    total_frames = parsed['total_frames']
    reported_bitrate = parsed['reported_bitrate_kbps']
    total_bits = sum(frames.values())
    frame_rate = FORCED_FRAME_RATE if FORCED_FRAME_RATE else derive_frame_rate(total_bits, total_frames, reported_bitrate)

    excluded_pocs = sorted(poc for poc in frames if poc + 1 in excluded_frame_indices)
    excluded_bits = sum(frames[poc] for poc in excluded_pocs)
    kept_bits = total_bits - excluded_bits

    all_frames_bitrate = (total_bits / total_frames) * frame_rate / 1000.0
    except_selected_bitrate = (kept_bits / total_frames) * frame_rate / 1000.0
    reduction_pct = 100.0 * (all_frames_bitrate - except_selected_bitrate) / all_frames_bitrate

    video_id = log_path.parent.parent.name
    qp = log_path.parent.name
    return [
        {
            'video_id': video_id,
            'qp': qp,
            'case': 'all_frames',
            'frame_indices': 'all',
            'pocs_removed': '',
            'bits_removed': 0,
            'total_bits_used': total_bits,
            'total_encoded_bits': total_bits,
            'total_frames_denominator': total_frames,
            'parsed_frame_count': len(frames),
            'derived_frame_rate': frame_rate,
            'bitrate_kbps': all_frames_bitrate,
            'reported_bitrate_kbps': reported_bitrate,
            'bitrate_reduction_pct': 0.0,
            'log_path': str(log_path),
        },
        {
            'video_id': video_id,
            'qp': qp,
            'case': 'all_except_8_16_24_32',
            'frame_indices': ','.join(map(str, excluded_frame_indices)),
            'pocs_removed': ','.join(map(str, excluded_pocs)),
            'bits_removed': excluded_bits,
            'total_bits_used': kept_bits,
            'total_encoded_bits': total_bits,
            'total_frames_denominator': total_frames,
            'parsed_frame_count': len(frames),
            'derived_frame_rate': frame_rate,
            'bitrate_kbps': except_selected_bitrate,
            'reported_bitrate_kbps': reported_bitrate,
            'bitrate_reduction_pct': reduction_pct,
            'log_path': str(log_path),
        },
    ]


bitrate_rows = []
for log_path in sorted(BITRATE_TESTING_ROOT.glob('*/*/encode.log')):
    bitrate_rows.extend(calculate_bitrate_rows(log_path))

if not bitrate_rows:
    raise RuntimeError(f'No encode.log files found under {BITRATE_TESTING_ROOT}')

bitrate_fieldnames = list(bitrate_rows[0].keys())
with open(BITRATE_SUMMARY_CSV, 'w', newline='', encoding='utf-8') as handle:
    writer = csv.DictWriter(handle, fieldnames=bitrate_fieldnames)
    writer.writeheader()
    writer.writerows(bitrate_rows)

print(f'Wrote bitrate summary: {BITRATE_SUMMARY_CSV}')
for row in bitrate_rows:
    print(
        f"{row['video_id']} {row['qp']} {row['case']}: "
        f"{row['bitrate_kbps']:.4f} kbps, "
        f"removed {row['bits_removed']} bits, "
        f"reduction {row['bitrate_reduction_pct']:.2f}%"
    )
# Out:
# Wrote bitrate summary: D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\frame_prediction_csvs2\bitrate_summary_C.csv
# BasketballDrill_832x480_50_C_416x240 QP_37 all_frames: 339.4875 kbps, removed 0 bits, reduction 0.00%
# BasketballDrill_832x480_50_C_416x240 QP_37 all_except_8_16_24_32: 312.4125 kbps, removed 17328 bits, reduction 7.98%
# BasketballDrill_832x480_50_C_416x240 QP_42 all_frames: 178.0875 kbps, removed 0 bits, reduction 0.00%
# BasketballDrill_832x480_50_C_416x240 QP_42 all_except_8_16_24_32: 164.1125 kbps, removed 8944 bits, reduction 7.85%
# BasketballDrill_832x480_50_C_416x240 QP_47 all_frames: 78.7750 kbps, removed 0 bits, reduction 0.00%
# BasketballDrill_832x480_50_C_416x240 QP_47 all_except_8_16_24_32: 72.8625 kbps, removed 3784 bits, reduction 7.51%
# BasketballDrill_832x480_50_C_416x240 QP_51 all_frames: 40.6375 kbps, removed 0 bits, reduction 0.00%
# BasketballDrill_832x480_50_C_416x240 QP_51 all_except_8_16_24_32: 37.3375 kbps, removed 2112 bits, reduction 8.12%
# BQMall_832x480_60_C_416x240 QP_37 all_frames: 450.7500 kbps, removed 0 bits, reduction 0.00%
# BQMall_832x480_60_C_416x240 QP_37 all_except_8_16_24_32: 418.1550 kbps, removed 17384 bits, reduction 7.23%
# BQMall_832x480_60_C_416x240 QP_42 all_frames: 231.9450 kbps, removed 0 bits, reduction 0.00%
# BQMall_832x480_60_C_416x240 QP_42 all_except_8_16_24_32: 214.9350 kbps, removed 9072 bits, reduction 7.33%
# BQMall_832x480_60_C_416x240 QP_47 all_frames: 112.4550 kbps, removed 0 bits, reduction 0.00%
# BQMall_832x480_60_C_416x240 QP_47 all_except_8_16_24_32: 105.1200 kbps, removed 3912 bits, reduction 6.52%
# BQMall_832x480_60_C_416x240 QP_51 all_frames: 61.5000 kbps, removed 0 bits, reduction 0.00%
# BQMall_832x480_60_C_416x240 QP_51 all_except_8_16_24_32: 56.8200 kbps, removed 2496 bits, reduction 7.61%
# PartyScene_832x480_50_C_416x240 QP_37 all_frames: 740.0625 kbps, removed 0 bits, reduction 0.00%
# PartyScene_832x480_50_C_416x240 QP_37 all_except_8_16_24_32: 676.5250 kbps, removed 40664 bits, reduction 8.59%
# PartyScene_832x480_50_C_416x240 QP_42 all_frames: 288.7875 kbps, removed 0 bits, reduction 0.00%
# PartyScene_832x480_50_C_416x240 QP_42 all_except_8_16_24_32: 265.9875 kbps, removed 14592 bits, reduction 7.90%
# PartyScene_832x480_50_C_416x240 QP_47 all_frames: 96.1500 kbps, removed 0 bits, reduction 0.00%
# PartyScene_832x480_50_C_416x240 QP_47 all_except_8_16_24_32: 89.4750 kbps, removed 4272 bits, reduction 6.94%
# PartyScene_832x480_50_C_416x240 QP_51 all_frames: 43.5125 kbps, removed 0 bits, reduction 0.00%
# PartyScene_832x480_50_C_416x240 QP_51 all_except_8_16_24_32: 41.1625 kbps, removed 1504 bits, reduction 5.40%
# RaceHorses_832x480_30_C_416x240 QP_37 all_frames: 361.4850 kbps, removed 0 bits, reduction 0.00%
# RaceHorses_832x480_30_C_416x240 QP_37 all_except_8_16_24_32: 325.9200 kbps, removed 37936 bits, reduction 9.84%
# RaceHorses_832x480_30_C_416x240 QP_42 all_frames: 176.7300 kbps, removed 0 bits, reduction 0.00%
# RaceHorses_832x480_30_C_416x240 QP_42 all_except_8_16_24_32: 161.0550 kbps, removed 16720 bits, reduction 8.87%
# RaceHorses_832x480_30_C_416x240 QP_47 all_frames: 83.5575 kbps, removed 0 bits, reduction 0.00%
# RaceHorses_832x480_30_C_416x240 QP_47 all_except_8_16_24_32: 76.4100 kbps, removed 7624 bits, reduction 8.55%
# RaceHorses_832x480_30_C_416x240 QP_51 all_frames: 45.3750 kbps, removed 0 bits, reduction 0.00%
# RaceHorses_832x480_30_C_416x240 QP_51 all_except_8_16_24_32: 41.5650 kbps, removed 4064 bits, reduction 8.40%

# %%
import os
import re
import pandas as pd
import numpy as np
from IPython.display import display, HTML

testing_dir = r"d:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\WQVGA\ClassC\encoded_C"
pred_times_dir = r"d:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\prediction_times2"
pred_csv = os.path.join(pred_times_dir, "prediction_times_C.csv")

if os.path.exists(pred_csv):
    pred_df = pd.read_csv(pred_csv)
else:
    pred_df = pd.DataFrame()

videos = [d for d in os.listdir(testing_dir) if os.path.isdir(os.path.join(testing_dir, d))]
qps = ["QP_37", "QP_42", "QP_47", "QP_51"]
target_frames = [8, 16, 24, 32]

detailed_results = []
summary_results = []

overall_delta_t_list = []

for video in videos:
    video_dir = os.path.join(testing_dir, video)
    
    video_delta_ts = {}
    
    for qp in qps:
        log_file = os.path.join(video_dir, qp, "encode.log")
        if not os.path.exists(log_file):
            continue
            
        ets = []
        with open(log_file, "r") as f:
            for line in f:
                match = re.search(r'\[ET\s+(\d+)\s*\]', line)
                if match:
                    poc_match = re.search(r'^POC\s+(\d+)', line)
                    if poc_match:
                        poc = int(poc_match.group(1))
                        et = float(match.group(1))
                        ets.append((poc, et))
                        
        ets.sort(key=lambda x: x[0])
        
        orig_time = 0.0
        enc_28_time = 0.0
        pred_time = 0.0
        
        for i, (poc, et) in enumerate(ets):
            frame_idx = i + 1
            orig_time += et
            
            if frame_idx in target_frames and not pred_df.empty:
                row = pred_df[(pred_df['qp'] == qp) & 
                              (pred_df['frame_index'] == frame_idx) & 
                              (pred_df['video_id'].str.contains(video))]
                if not row.empty:
                    pred_time += row.iloc[0]['pred_time_sec']
                else:
                    pred_time += et
            elif frame_idx in target_frames and pred_df.empty:
                pred_time += et
            else:
                enc_28_time += et
                
        prop_time = enc_28_time + pred_time
        
        if orig_time > 0:
            delta_t = ((orig_time - prop_time) / orig_time) * 100
            video_delta_ts[qp] = delta_t
            overall_delta_t_list.append(delta_t)
            
            detailed_results.append({
                "Video": video,
                "QP": qp.replace("QP_", ""),
                "Original 32 (s)": f"{orig_time:.2f}",
                "28 Encoded (s)": f"{enc_28_time:.2f}",
                "Prediction (s)": f"{pred_time:.2f}",
                "Proposed (s)": f"{prop_time:.2f}",
                "ΔT (%)": f"{delta_t:.2f}"
            })
            
    if len(video_delta_ts) > 0:
        avg_dt = sum(video_delta_ts.values()) / len(video_delta_ts)
        summary_results.append({
            "Video": video,
            "ΔT @QP37": f"{video_delta_ts.get('QP_37', 0):.2f}",
            "ΔT @QP42": f"{video_delta_ts.get('QP_42', 0):.2f}",
            "ΔT @QP47": f"{video_delta_ts.get('QP_47', 0):.2f}",
            "ΔT @QP51": f"{video_delta_ts.get('QP_51', 0):.2f}",
            "Average ΔT": f"{avg_dt:.2f}"
        })

if summary_results:
    # Add Overall Average Row
    overall_avg = sum(overall_delta_t_list) / len(overall_delta_t_list) if overall_delta_t_list else 0
    # Calculate average per QP across all videos
    avg_qp37 = np.mean([float(r["ΔT @QP37"]) for r in summary_results if r["ΔT @QP37"] != "0.00"]) if summary_results else 0
    avg_qp42 = np.mean([float(r["ΔT @QP42"]) for r in summary_results if r["ΔT @QP42"] != "0.00"]) if summary_results else 0
    avg_qp47 = np.mean([float(r["ΔT @QP47"]) for r in summary_results if r["ΔT @QP47"] != "0.00"]) if summary_results else 0
    avg_qp51 = np.mean([float(r["ΔT @QP51"]) for r in summary_results if r["ΔT @QP51"] != "0.00"]) if summary_results else 0
    
    summary_results.append({
        "Video": "Overall Average",
        "ΔT @QP37": f"{avg_qp37:.2f}",
        "ΔT @QP42": f"{avg_qp42:.2f}",
        "ΔT @QP47": f"{avg_qp47:.2f}",
        "ΔT @QP51": f"{avg_qp51:.2f}",
        "Average ΔT": f"{overall_avg:.2f}"
    })

df_summary = pd.DataFrame(summary_results)
df_detailed = pd.DataFrame(detailed_results)

display(HTML("<h3>Summary of ΔT (%)</h3>"))
display(df_summary)

display(HTML("<h3>Detailed Breakdown</h3>"))
display(df_detailed)

# Save results to CSV
df_summary.to_csv(os.path.join(testing_dir, 'summary_delta_t.csv'), index=False)
df_detailed.to_csv(os.path.join(testing_dir, 'detailed_delta_t.csv'), index=False)
print('Saved results to summary_delta_t.csv and detailed_delta_t.csv in Testing_ClassA folder.')
# Out:
# <h3>Summary of ΔT (%)</h3>
#                                   Video ΔT @QP37 ΔT @QP42 ΔT @QP47 ΔT @QP51  \
# 0  BasketballDrill_832x480_50_C_416x240    12.12    10.99    10.92     6.81
# 1           BQMall_832x480_60_C_416x240    11.37    10.87     8.92     8.26
# 2       PartyScene_832x480_50_C_416x240    11.23    11.81    11.36     5.13
# 3       RaceHorses_832x480_30_C_416x240    11.54    12.25    11.43     8.48
# 4                       Overall Average    11.56    11.48    10.66     7.17
#
#   Average ΔT
# 0      10.21
# 1       9.86
# 2       9.88
# 3      10.93
# 4      10.22
# <h3>Detailed Breakdown</h3>
#                                    Video  QP Original 32 (s) 28 Encoded (s)  \
# 0   BasketballDrill_832x480_50_C_416x240  37          257.00         221.00
# 1   BasketballDrill_832x480_50_C_416x240  42          166.00         143.00
# 2   BasketballDrill_832x480_50_C_416x240  47           86.00          72.00
# 3   BasketballDrill_832x480_50_C_416x240  51           49.00          41.00
# 4            BQMall_832x480_60_C_416x240  37          223.00         193.00
# 5            BQMall_832x480_60_C_416x240  42          141.00         121.00
# 6            BQMall_832x480_60_C_416x240  47           81.00          69.00
# 7            BQMall_832x480_60_C_416x240  51           63.00          53.00
# 8        PartyScene_832x480_50_C_416x240  37          359.00         314.00
# 9        PartyScene_832x480_50_C_416x240  42          233.00         200.00
# 10       PartyScene_832x480_50_C_416x240  47          104.00          87.00
# 11       PartyScene_832x480_50_C_416x240  51           52.00          44.00
# 12       RaceHorses_832x480_30_C_416x240  37          359.00         312.00
# 13       RaceHorses_832x480_30_C_416x240  42          266.00         228.00
# 14       RaceHorses_832x480_30_C_416x240  47          141.00         119.00
# 15       RaceHorses_832x480_30_C_416x240  51           83.00          71.00
#
#    Prediction (s) Proposed (s) ΔT (%)
# 0            4.84       225.84  12.12
# 1            4.75       147.75  10.99
# 2            4.61        76.61  10.92
# 3            4.66        45.66   6.81
# 4            4.65       197.65  11.37
# 5            4.67       125.67  10.87
# 6            4.77        73.77   8.92
# 7            4.79        57.79   8.26
# 8            4.67       318.67  11.23
# 9            5.49       205.49  11.81
# 10           5.19        92.19  11.36
# 11           5.33        49.33   5.13
# 12           5.56       317.56  11.54
# 13           5.40       233.40  12.25
# 14           5.88       124.88  11.43
# 15           4.97        75.97   8.48
# Saved results to summary_delta_t.csv and detailed_delta_t.csv in Testing_ClassA folder.

# %%
import torch
import matplotlib.pyplot as plt
import os

# Set this environment variable if you encounter the OpenMP duplicate library error
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# Load the checkpoint
checkpoint_path = 'myown_fast_last_checkpoint.pth'
checkpoint = torch.load(checkpoint_path, map_location='cpu')

# Extract the history
history = checkpoint.get('history', {})

if history:
    epochs = range(1, len(history['train_loss']) + 1)

    # 1. Plot Loss Curve
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, history['train_loss'], label='Training Loss', marker='o')
    plt.plot(epochs, history['val_loss'], label='Validation Loss', marker='o')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # 2. Plot PSNR Curve
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, history['train_psnr'], label='Training PSNR', marker='o')
    plt.plot(epochs, history['val_psnr'], label='Validation PSNR', marker='o')
    plt.title('Training and Validation PSNR')
    plt.xlabel('Epochs')
    plt.ylabel('PSNR (dB)')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # 3. Plot Validation SSIM Curve
    if 'val_ssim' in history:
        plt.figure(figsize=(10, 5))
        plt.plot(epochs, history['val_ssim'], label='Validation SSIM', marker='o', color='green')
        plt.title('Validation SSIM')
        plt.xlabel('Epochs')
        plt.ylabel('SSIM')
        plt.legend()
        plt.grid(True)
        plt.show()
else:
    print("No history found in the checkpoint.")

# %%
import os
import re
from pathlib import Path
import numpy as np
import torch
import torch.nn.functional as F

# --- Configuration ---
# Set False to use fixed 416x240 resolution.
# Set True to dynamically extract the LAST resolution found in the folder name.
USE_DYNAMIC_RES = False
FIXED_WIDTH = 416
FIXED_HEIGHT = 240
# ---------------------

# ==========================================================
# 1. Device and model
# ==========================================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model_path = r"d:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\myown_fast_best_model_final.pth"

print(f"Loading weights from: {model_path}")

base_model = FastTemporalUNet(T=7, base_ch=48)
base_model.load_state_dict(torch.load(model_path, map_location=device))
base_model.to(device)
base_model.eval()

# ==========================================================
# 2. Root directory
# ==========================================================
base_dir = Path(
    r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\WQVGA\ClassC\encoded_C"
)

target_frames = [8, 16, 24, 32]

# ==========================================================
# 3. Process every video
# ==========================================================
for video_dir in sorted(base_dir.iterdir()):

    if not video_dir.is_dir():
        continue

    print("\n===================================================")
    print(video_dir.name)
    print("===================================================")

    if USE_DYNAMIC_RES:
        # Using findall and $[-1]$ ensures we pick 416x240 instead of 2560x1600 in names like "Traffic_2560x1600_30_C_416x240"
        matches = re.findall(r'(\d+)x(\d+)', video_dir.name)
        if not matches:
            print("Cannot determine resolution. Skipping.")
            continue
        width, height = int(matches[-1][0]), int(matches[-1][1])
    else:
        width, height = FIXED_WIDTH, FIXED_HEIGHT

    frame_size = width * height * 3 // 2
    y_size = width * height
    uv_size = y_size // 4

    # ------------------------------------------------------
    # Process every QP folder
    # ------------------------------------------------------
    for qp_dir in sorted(video_dir.glob("QP_*")):

        input_files = list(qp_dir.glob("C_*.yuv"))

        if len(input_files) == 0:
            continue

        input_yuv = input_files[0]
        output_yuv = qp_dir / input_yuv.name.replace("C_", "P_", 1)

        print(f"\n{qp_dir.name}")
        print(f"Input : {input_yuv.name}")
        print(f"Output: {output_yuv.name}")

        # --------------------------------------------------
        # Read YUV
        # --------------------------------------------------
        with open(input_yuv, "rb") as f:
            raw_data = f.read()

        num_frames = len(raw_data) // frame_size

        y_frames = []
        u_frames = []
        v_frames = []

        for i in range(num_frames):

            start = i * frame_size

            y = np.frombuffer(
                raw_data[start:start+y_size],
                dtype=np.uint8
            ).copy().reshape(height, width)

            u = np.frombuffer(
                raw_data[start+y_size:start+y_size+uv_size],
                dtype=np.uint8
            ).copy().reshape(height//2, width//2)

            v = np.frombuffer(
                raw_data[start+y_size+uv_size:start+frame_size],
                dtype=np.uint8
            ).copy().reshape(height//2, width//2)

            y_frames.append(y)
            u_frames.append(u)
            v_frames.append(v)

        # --------------------------------------------------
        # Predict frames
        # --------------------------------------------------
        for target_frame in target_frames:

            if target_frame > num_frames:
                continue

            t_idx = target_frame - 1

            input_indices = list(range(t_idx-7, t_idx))

            input_y = np.stack(
                [y_frames[idx] for idx in input_indices],
                axis=0
            ).astype(np.float32) / 255.0

            input_tensor = torch.from_numpy(input_y).unsqueeze(1)

            input_tensor = F.interpolate(
                input_tensor,
                size=(512, 512),
                mode="bilinear",
                align_corners=False
            )

            model_input = input_tensor.unsqueeze(0).to(device)

            with torch.no_grad():
                pred = base_model(model_input)

            pred = F.interpolate(
                pred,
                size=(height, width),
                mode="bilinear",
                align_corners=False
            )

            pred = pred.squeeze().cpu().numpy()

            pred = np.clip(
                np.round(pred * 255.0),
                0,
                255
            ).astype(np.uint8)

            y_frames[t_idx] = pred

            print(f"Predicted frame {target_frame}")

        # --------------------------------------------------
        # Save YUV
        # --------------------------------------------------
        with open(output_yuv, "wb") as f:

            for y, u, v in zip(y_frames, u_frames, v_frames):
                f.write(y.tobytes())
                f.write(u.tobytes())
                f.write(v.tobytes())

        print("Saved:", output_yuv.name)

print("\nFinished processing all videos.")
# Out:
# Using device: cuda
# Loading weights from: d:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\myown_fast_best_model_final.pth
#
# ===================================================
# BasketballDrill_832x480_50_C_416x240
# ===================================================
#
# QP_37
# Input : C_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# Output: P_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
#
# QP_42
# Input : C_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# Output: P_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
#
# QP_47
# Input : C_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# Output: P_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
#
# QP_51
# Input : C_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# Output: P_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
#
# ===================================================
# BQMall_832x480_60_C_416x240
# ===================================================
#
# QP_37
# Input : C_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32.yuv
# Output: P_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32.yuv
#
# QP_42
# Input : C_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32.yuv
# Output: P_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32.yuv
#
# QP_47
# Input : C_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32.yuv
# Output: P_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32.yuv
#
# QP_51
# Input : C_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32.yuv
# Output: P_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32.yuv
#
# ===================================================
# PartyScene_832x480_50_C_416x240
# ===================================================
#
# QP_37
# Input : C_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# Output: P_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
#
# QP_42
# Input : C_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# Output: P_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
#
# QP_47
# Input : C_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# Output: P_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
#
# QP_51
# Input : C_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# Output: P_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
#
# ===================================================
# RaceHorses_832x480_30_C_416x240
# ===================================================
#
# QP_37
# Input : C_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32.yuv
# Output: P_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32.yuv
#
# QP_42
# Input : C_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32.yuv
# Output: P_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32.yuv
#
# QP_47
# Input : C_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32.yuv
# Output: P_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32.yuv
#
# QP_51
# Input : C_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32.yuv
# Output: P_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32.yuv
# Predicted frame 8
# Predicted frame 16
# Predicted frame 24
# Predicted frame 32
# Saved: P_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32.yuv
#
# Finished processing all videos.

# %%
import re
import subprocess
from pathlib import Path

# --- Configuration ---
# Set False to enforce fixed 416x240 resolution.
# Set True to dynamically extract the LAST resolution found in the video folder name.
USE_DYNAMIC_RES = False
FIXED_WIDTH = "416"
FIXED_HEIGHT = "240"
DEFAULT_FPS = "60"
# ---------------------

# ==========================================================
# Paths
# ==========================================================
ROOT = Path(r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8")

recon_root = ROOT / "Original/WQVGA/ClassC/encoded_C"
original_root = ROOT / "Original/WQVGA/ClassC"
output_root = ROOT / "frame_prediction_csvs2" / "ClassC"

qps = [37, 42, 47, 51]

# ==========================================================
# Process every sequence
# ==========================================================
for video_dir in sorted(recon_root.iterdir()):

    if not video_dir.is_dir():
        continue

    video_name = video_dir.name

    print("\n" + "=" * 80)
    print(f"Processing: {video_name}")
    print("=" * 80)

    # 1. Determine Resolution
    if USE_DYNAMIC_RES:
        res_matches = re.findall(r"(\d+)x(\d+)", video_name)
        if not res_matches:
            print("Cannot determine resolution from name. Skipping.")
            continue
        width, height = res_matches[-1][0], res_matches[-1][1]
    else:
        width, height = FIXED_WIDTH, FIXED_HEIGHT

    # 2. Determine FPS (searches for numbers immediately following a resolution block, e.g., 2560x1600_30)
    fps_match = re.search(r"\d+x\d+_(\d+)", video_name)
    fps = fps_match.group(1) if fps_match else DEFAULT_FPS
    print(f"Using settings: {width}x{height} @ {fps}fps")

    # 3. Locate Original Ground-Truth YUV
    original_yuv = original_root / f"{video_name}_F32.yuv"
    if not original_yuv.exists():
        # Fallback search using glob if exact name doesn't match
        matches = list(original_root.glob(f"*{video_name}*.yuv"))
        if matches:
            original_yuv = matches[0]
        else:
            print(f"Missing pre-trimmed 32-frame original in {original_root}")
            continue

    # 4. Process QPs
    for qp in qps:
        qp_dir = video_dir / f"QP_{qp}"
        if not qp_dir.exists():
            continue

        # Use globbing to robustly find C_ and P_ files without breaking on suffixes like _F32.yuv
        c_files = list(qp_dir.glob("C_*.yuv"))
        p_files = list(qp_dir.glob("P_*.yuv"))

        jobs = []
        if c_files:
            jobs.append((c_files[0], "vmaf.json"))
        else:
            print(f"Missing C_*.yuv in {qp_dir.name}")
            
        if p_files:
            jobs.append((p_files[0], "vmaf2.json"))
        else:
            print(f"Missing P_*.yuv in {qp_dir.name}")

        for dist_yuv, json_name in jobs:
            out_dir = output_root / video_name / f"QP_{qp}"
            out_dir.mkdir(parents=True, exist_ok=True)

            filter_str = f"libvmaf=log_path={json_name}:log_fmt=json"

            cmd = [
                "ffmpeg",
                "-y",
                "-video_size", f"{width}x{height}",
                "-pix_fmt", "yuv420p",
                "-framerate", fps,
                "-i", str(dist_yuv),
                "-video_size", f"{width}x{height}",
                "-pix_fmt", "yuv420p",
                "-framerate", fps,
                "-i", str(original_yuv),
                "-filter_complex", filter_str,
                "-f", "null", "-"
            ]

            print(f"\nQP {qp} -> {dist_yuv.name}")

            result = subprocess.run(
                cmd,
                cwd=out_dir,
                stdout=subprocess.PIPE,
                stderr=subprocess.STDOUT,
                text=True
            )

            if result.returncode == 0:
                print(f"✓ {json_name} created")
            else:
                print(f"✗ Failed ({json_name})")
                print(result.stdout[:300])  # Print first 300 chars of FFmpeg error for easier debugging

print("\nFinished.")
# Out:
# ================================================================================
# Processing: BasketballDrill_832x480_50_C_416x240
# ================================================================================
# Using settings: 416x240 @ 50fps
#
# QP 37 -> C_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 37 -> P_BasketballDrill_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 42 -> C_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 42 -> P_BasketballDrill_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 47 -> C_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 47 -> P_BasketballDrill_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 51 -> C_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 51 -> P_BasketballDrill_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# ================================================================================
# Processing: BQMall_832x480_60_C_416x240
# ================================================================================
# Using settings: 416x240 @ 60fps
#
# QP 37 -> C_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 37 -> P_BQMall_832x480_60_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 42 -> C_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 42 -> P_BQMall_832x480_60_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 47 -> C_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 47 -> P_BQMall_832x480_60_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 51 -> C_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 51 -> P_BQMall_832x480_60_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# ================================================================================
# Processing: PartyScene_832x480_50_C_416x240
# ================================================================================
# Using settings: 416x240 @ 50fps
#
# QP 37 -> C_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 37 -> P_PartyScene_832x480_50_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 42 -> C_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 42 -> P_PartyScene_832x480_50_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 47 -> C_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 47 -> P_PartyScene_832x480_50_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 51 -> C_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 51 -> P_PartyScene_832x480_50_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# ================================================================================
# Processing: RaceHorses_832x480_30_C_416x240
# ================================================================================
# Using settings: 416x240 @ 30fps
#
# QP 37 -> C_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 37 -> P_RaceHorses_832x480_30_C_416x240_QP_37_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 42 -> C_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 42 -> P_RaceHorses_832x480_30_C_416x240_QP_42_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 47 -> C_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 47 -> P_RaceHorses_832x480_30_C_416x240_QP_47_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# QP 51 -> C_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf.json created
#
# QP 51 -> P_RaceHorses_832x480_30_C_416x240_QP_51_F_1_to_32.yuv
# ✓ vmaf2.json created
#
# Finished.

# %% [markdown]
# ## Extract First 32 Frames from Original YUV Files
#
# Uses `ffmpeg` to extract the first 32 frames from every `.yuv` file in the `Original` directory and saves each as `<basename>_F32.yuv` in its original folder.

# %%
import os
import re
import subprocess
from pathlib import Path

# --- Configuration ---
# Set to True to dynamically extract resolution from filename via regex.
# Set to False to enforce fixed 416x240 resolution for all YUV files.
USE_DYNAMIC_RES = False
FIXED_WIDTH = "416"
FIXED_HEIGHT = "240"
# ---------------------

orig_dir = Path(r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\WQVGA\ClassA")
if not orig_dir.exists():
    orig_dir = Path("./Original")

yuv_files = sorted(orig_dir.rglob("*.yuv"))

for yuv_path in yuv_files:
    if yuv_path.name.endswith("_F32.yuv"):
        continue
    
    if USE_DYNAMIC_RES:
        match = re.search(r"(\d+)x(\d+)", yuv_path.name)
        if not match:
            print(f"Skipping {yuv_path.name}: resolution not found in filename")
            continue
        width, height = match.group(1), match.group(2)
    else:
        width, height = FIXED_WIDTH, FIXED_HEIGHT
    
    output_name = f"{yuv_path.stem}_F32.yuv"
    output_path = yuv_path.parent / output_name
    
    cmd = [
        "ffmpeg", "-y",
        "-f", "rawvideo",
        "-pix_fmt", "yuv420p",
        "-video_size", f"{width}x{height}",
        "-framerate", "60",
        "-i", str(yuv_path),
        "-frames:v", "32",
        "-f", "rawvideo",
        str(output_path)
    ]
    
    print(f"Extracting {yuv_path.name} ({width}x{height}) -> {output_name}")
    res = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    if res.returncode == 0:
        print(f"  [OK] Saved {output_path.name} ({output_path.stat().st_size:,} bytes)")
    else:
        print(f"  [ERROR] {res.stderr[:200]}")
# Out:
# Extracting C_Traffic_2560x1600_30_C_416x240_QP_37_F_1_to_32.yuv (416x240) -> C_Traffic_2560x1600_30_C_416x240_QP_37_F_1_to_32_F32.yuv
#   [OK] Saved C_Traffic_2560x1600_30_C_416x240_QP_37_F_1_to_32_F32.yuv (4,792,320 bytes)
# Extracting C_Traffic_2560x1600_30_C_416x240_QP_42_F_1_to_32.yuv (416x240) -> C_Traffic_2560x1600_30_C_416x240_QP_42_F_1_to_32_F32.yuv
#   [OK] Saved C_Traffic_2560x1600_30_C_416x240_QP_42_F_1_to_32_F32.yuv (4,792,320 bytes)
# Extracting C_Traffic_2560x1600_30_C_416x240_QP_47_F_1_to_32.yuv (416x240) -> C_Traffic_2560x1600_30_C_416x240_QP_47_F_1_to_32_F32.yuv
#   [OK] Saved C_Traffic_2560x1600_30_C_416x240_QP_47_F_1_to_32_F32.yuv (4,792,320 bytes)
# Extracting C_Traffic_2560x1600_30_C_416x240_QP_51_F_1_to_32.yuv (416x240) -> C_Traffic_2560x1600_30_C_416x240_QP_51_F_1_to_32_F32.yuv
#   [OK] Saved C_Traffic_2560x1600_30_C_416x240_QP_51_F_1_to_32_F32.yuv (4,792,320 bytes)
# Extracting Traffic_2560x1600_30_C_416x240.yuv (416x240) -> Traffic_2560x1600_30_C_416x240_F32.yuv
#   [OK] Saved Traffic_2560x1600_30_C_416x240_F32.yuv (4,792,320 bytes)

# %%
import os
import cv2
import torch
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# Create output directory for thesis images
out_dir = Path(r"D:/Dataset/Inter4K/60fps/UHD/Segments/sevtone_4_QP_GOP8/thesis_template/chapters/images/tonmoy_results")
out_dir.mkdir(exist_ok=True, parents=True)

# Helper to read YUV
def read_yuv420_y_frames(yuv_path, width, height):
    frame_size = width * height * 3 // 2
    raw = np.fromfile(yuv_path, dtype=np.uint8)
    n_frames = len(raw) // frame_size
    frames = []
    for i in range(n_frames):
        start = i * frame_size
        y_plane = raw[start : start + width * height].reshape(height, width)
        frames.append(y_plane)
    return np.array(frames)

# Videos to demo
videos_to_demo = {
    'Class D': ('BasketballPass_416x240_50', 416, 240, r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\ClassD", r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Reconstructed\Testing_ClassD"),
    'Class C': ('BQMall_832x480_60', 832, 480, r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\ClassC", r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Reconstructed\Testing_ClassC"),
    'Class B': ('Cactus_1920x1080_50', 1920, 1080, r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\ClassB", r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Reconstructed\Testing_ClassB"),
    'Class A': ('Traffic_2560x1600_30', 2560, 1600, r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Original\ClassA", r"D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\Reconstructed\Testing_ClassA")
}

# Ensure model is in eval mode
if 'model' in globals():
    model.eval()
else:
    print("Model not in memory, make sure to run previous cells!")

QP = "QP_37" 

for cls_name, (vid_name, w, h, orig_dir, recon_dir) in videos_to_demo.items():
    orig_path = Path(orig_dir) / f"{vid_name}.yuv"
    recon_path = Path(recon_dir) / vid_name / QP / f"C_{vid_name}_{QP}_F_1_to_32.yuv"
    
    if not recon_path.exists():
        print(f"Skipping {vid_name}: {recon_path} not found.")
        continue
        
    # Read first 8 frames from reconstructed (1-7 for input, 8 for baseline target)
    recon_frames = read_yuv420_y_frames(recon_path, w, h)
    if len(recon_frames) < 8:
        print(f"Not enough frames in {recon_path}")
        continue
        
    target_frame = recon_frames[7] 
    
    # Interpolate target frame to 512x512 to match the model input/output
    target_frame = cv2.resize(target_frame, (512, 512), interpolation=cv2.INTER_LINEAR)
    
    input_frames = recon_frames[:7] 
    
    # Prepare input tensor
    x = input_frames.astype(np.float32) / 255.0
    
    if 'DEVICE' not in globals():
        DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
    x = torch.from_numpy(x).unsqueeze(1).unsqueeze(0).to(DEVICE) 
    
    # Interpolate input to 512x512
    x_resized = torch.nn.functional.interpolate(x.squeeze(2), size=(512, 512), mode='bilinear').unsqueeze(2)
        
    # Predict
    with torch.no_grad():
        if 'model' in globals():
            y_p = model(x_resized)
            pred_frame = (y_p[0, 0].cpu().numpy() * 255.0).clip(0, 255).astype(np.uint8)
        else:
            pred_frame = np.zeros_like(target_frame) 
    
    # Plot and save
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(target_frame, cmap='gray')
    axes[0].set_title(f"Encoded 8th Frame ({vid_name}) [512x512]")
    axes[0].axis('off')
    
    axes[1].imshow(pred_frame, cmap='gray')
    axes[1].set_title(f"Predicted 8th Frame (FastTemporalUNet) [512x512]")
    axes[1].axis('off')
    
    save_path = out_dir / f"{vid_name}_prediction.png"
    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight')
    plt.close(fig)
    print(f"Saved side-by-side to {save_path}")
# Out:
# Saved side-by-side to D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\thesis_template\chapters\images\tonmoy_results\BasketballPass_416x240_50_prediction.png
# Saved side-by-side to D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\thesis_template\chapters\images\tonmoy_results\BQMall_832x480_60_prediction.png
# Saved side-by-side to D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\thesis_template\chapters\images\tonmoy_results\Cactus_1920x1080_50_prediction.png
# Saved side-by-side to D:\Dataset\Inter4K\60fps\UHD\Segments\sevtone_4_QP_GOP8\thesis_template\chapters\images\tonmoy_results\Traffic_2560x1600_30_prediction.png
